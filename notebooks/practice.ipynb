# %%
# !pip install missingno

# %%
import pandas as pd

import missingno as msno

import eda_helper_functions as eda

# %%
df = pd.read_csv("titanic.csv")
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 25            26         1       3
# 72            73         0       2
# 10            11         1       3
# 197          198         0       3
# 356          357         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 72                                Hood, Mr. Ambrose Jr    male  21.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 197                   Olsen, Mr. Karl Siegwart Andreas    male  42.0      0
# 356                        Bowerman, Miss. Elsie Edith  female  22.0      0
#
#      Parch        Ticket     Fare Cabin Embarked
# 25       5        347077  31.3875   NaN        S
# 72       0  S.O.C. 14879  73.5000   NaN        S
# 10       1       PP 9549  16.7000    G6        S
# 197      1          4579   8.4042   NaN        S
# ...

# %% [markdown]
# # missingno - Tutorial

# %% [markdown]
# ## 1. Matrix

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Bar

# %%
msno.bar(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 3. Heatmap

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %% [markdown]
# ## 4. Dendrogram

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %% [markdown]
# ## EDA Helper Functions

# %%
cars = pd.read_csv("car-details.csv")
cars.sample(5)
# Out:
#                                            name  company  model  \
# 3826  Maruti Swift VDI Windsong Limited edition   Maruti  Swift
# 2792                Hyundai i10 Sportz 1.1L LPG  Hyundai    i10
# 5779                 Maruti Wagon R VXI Opt 1.2   Maruti  Wagon
# 1676                   Hyundai Creta 1.4 CRDi S  Hyundai  Creta
# 182                      Maruti Swift Dzire VXI   Maruti  Swift
#
#                            edition  year  owner    fuel seller_type  \
# 3826  VDI Windsong Limited edition  2015  First  Diesel      Dealer
# 2792               Sportz 1.1L LPG  2015  First     LPG  Individual
# 5779                 R VXI Opt 1.2  2017  First  Petrol  Individual
# 1676                    1.4 CRDi S  2018  First  Diesel  Individual
# 182                      Dzire VXI  2014  First  Petrol  Individual
#
#      transmission  km_driven  mileage_mpg  engine_cc  max_power_bhp  \
# 3826       Manual     114000     59.22000     1248.0          73.94
# ...

# %%
eda.cat_bivar_plots(cars, "seller_type", "owner")
# Out:
# <h2>Bi-variate Analysis between seller_type and owner</h2>
# <h3></h3>

# %%
train = pd.read_csv("train.csv")
train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info  price
# ...

# %%
train.airline.value_counts()
# Out:
# airline
# Jet Airways          248
# Indigo               115
# Air India            102
# Multiple Carriers     68
# Spicejet              40
# Vistara               36
# Air Asia              18
# Goair                 13
# Name: count, dtype: int64

# %%
train.airline.value_counts(normalize=True)
# Out:
# airline
# Jet Airways          0.387500
# Indigo               0.179688
# Air India            0.159375
# Multiple Carriers    0.106250
# Spicejet             0.062500
# Vistara              0.056250
# Air Asia             0.028125
# Goair                0.020313
# Name: proportion, dtype: float64
